# %%
df_original = df.copy()

# %%
df_100 = df.head(100)

# %%
df_100
# Out:
#    user_id course_id   timestamp  engagement_score completion_status  \
# 0     U133      C015  2023-07-02          0.348821       In Progress
# 1     U029      C029  2023-06-02          0.110998         Completed
# 2     U132      C029  2023-11-11          0.808235       In Progress
# 3     U138      C011  2023-11-30          0.947688       In Progress
# 4     U184      C032  2023-05-04          0.072316       In Progress
# ..     ...       ...         ...               ...               ...
# 95    U018      C022  2023-01-20          0.360050       Not Started
# 96    U038      C024  2023-03-16          0.956800         Completed
# 97    U115      C041  2023-08-31          0.500401       Not Started
# 98    U015      C017  2023-08-11          0.432729         Completed
# 99    U192      C012  2023-03-11          0.457700       In Progress
#
#     predicted_engagement_score  assessment_score  feedback_score  age  \
# ...

# %%
df_100 = df.head(100)

data = df_100[['user_id','preferred_topics','title']]

# %%
student_courses = {}

for index, row in data.iterrows():
    user = row['user_id']
    course = row['title']
    
    if user not in student_courses:
        student_courses[user] = []
        
    student_courses[user].append(course)

student_courses
# Out:
# {'U133': ['Course 15', 'Course 7'],
#  'U029': ['Course 29'],
#  'U132': ['Course 29', 'Course 3', 'Course 38'],
#  'U138': ['Course 11'],
#  'U184': ['Course 32', 'Course 15'],
#  'U145': ['Course 2'],
#  'U074': ['Course 47'],
#  'U017': ['Course 14'],
#  'U084': ['Course 20'],
#  'U069': ['Course 22'],
#  'U034': ['Course 11', 'Course 24'],
#  'U006': ['Course 27'],
#  'U053': ['Course 3'],
#  'U194': ['Course 17'],
#  'U126': ['Course 44'],
#  'U043': ['Course 28'],
#  'U115': ['Course 29', 'Course 25', 'Course 41'],
#  'U111': ['Course 21', 'Course 41'],
#  'U151': ['Course 47', 'Course 8'],
#  'U183': ['Course 16'],
#  'U080': ['Course 37'],
#  'U095': ['Course 20'],
#  'U118': ['Course 6'],
#  'U144': ['Course 19'],
#  'U008': ['Course 5', 'Course 8'],
#  'U104': ['Course 1'],
#  'U025': ['Course 34'],
#  'U195': ['Course 35', 'Course 25'],
#  'U096': ['Course 49'],
#  'U155': ['Course 24', 'Course 15'],
#  'U093': ['Course 12'],
#  'U160': ['Course 18'],
# ...

# %%
interest_courses = {
    'Data Science': ['Python', 'ML', 'Statistics'],
    'AI': ['Deep Learning', 'NLP'],
    'Programming': ['Java', 'Python']
}

# %%
import matplotlib.pyplot as plt

interest_count = {}

for key, value in interest_courses.items():
    interest_count[key] = len(value)

print(interest_count)
# Out:
# {'Data Science': 3, 'AI': 2, 'Programming': 2}

# %%
plt.bar(interest_count.keys(), interest_count.values())

plt.xlabel("Student Interest")
plt.ylabel("Number of Courses")
plt.title("Courses Recommended Based on Interest")

plt.xticks(rotation=45)
plt.show()

# %%
topic_count = df_100['topic'].value_counts()

topic_count.plot(kind='bar')

plt.xlabel("Topics")
plt.ylabel("Number of Students")
plt.title("Student Interest Distribution")

plt.xticks(rotation=45)
plt.show()

# %%
status = df_100['completion_status'].value_counts()

status.plot(kind='bar')

plt.xlabel("Completion Status")
plt.ylabel("Count")
plt.title("Course Completion Status")

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("learning.csv")

df.head()
# Out:
#   user_id course_id   timestamp  engagement_score completion_status  \
# 0    U133      C015  2023-07-02          0.348821       In Progress
# 1    U029      C029  2023-06-02          0.110998         Completed
# 2    U132      C029  2023-11-11          0.808235       In Progress
# 3    U138      C011  2023-11-30          0.947688       In Progress
# 4    U184      C032  2023-05-04          0.072316       In Progress
#
#    predicted_engagement_score  assessment_score  feedback_score  age  \
# 0                    0.162183                64            4.40   49
# 1                    0.486442                81            4.43   45
# 2                    0.738539                64            4.69   56
# 3                    0.866855                63            2.57   56
# 4                    0.626259                68            3.90   19
#
#   education_level learning_style preferred_topics      title         topic  \
# ...

# %%
df.isnull().sum()
# Out:
# user_id                       0
# course_id                     0
# timestamp                     0
# engagement_score              0
# completion_status             0
# predicted_engagement_score    0
# assessment_score              0
# feedback_score                0
# age                           0
# education_level               0
# learning_style                0
# preferred_topics              0
# title                         0
# topic                         0
# difficulty                    0
# content_type                  0
# dtype: int64

# %%
df.fillna("Unknown", inplace=True)

# %%
df['assessment_score'].fillna(
    df['assessment_score'].mean(),
    inplace=True
)
# Out:
# C:\Users\student\AppData\Local\Temp\ipykernel_3272\4025273709.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['assessment_score'].fillna(

# %%
print("Original Dataset:", df_original.shape)
print("Working Dataset:", df_100.shape)
# Out:
# Original Dataset: (1007, 16)
# Working Dataset: (100, 16)

# %%
df_100.isnull().sum()
# Out:
# user_id                       0
# course_id                     0
# timestamp                     0
# engagement_score              0
# completion_status             0
# predicted_engagement_score    0
# assessment_score              0
# feedback_score                0
# age                           0
# education_level               0
# learning_style                0
# preferred_topics              0
# title                         0
# topic                         0
# difficulty                    0
# content_type                  0
# dtype: int64

# %%
df_100.duplicated().sum()
# Out:
# 0

# %%
df_100.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   user_id                     100 non-null    object
#  1   course_id                   100 non-null    object
#  2   timestamp                   100 non-null    object
#  3   engagement_score            100 non-null    float64
#  4   completion_status           100 non-null    object
#  5   predicted_engagement_score  100 non-null    float64
#  6   assessment_score            100 non-null    int64
#  7   feedback_score              100 non-null    float64
#  8   age                         100 non-null    int64
#  9   education_level             100 non-null    object
#  10  learning_style              100 non-null    object
#  11  preferred_topics            100 non-null    object
#  12  title                       100 non-null    object
# ...

# %%
transactions = df_100.groupby('user_id')['title'].apply(list)

transactions.head()
# Out:
# user_id
# U001    [Course 50, Course 24]
# U003               [Course 38]
# U005               [Course 25]
# U006               [Course 27]
# U007               [Course 33]
# Name: title, dtype: object

# %%
df1=pd.read_csv("courses.csv")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df1 = pd.read_csv("courses.csv")

df1.head()
# Out:
#    course_id                                       course_title  \
# 0        134  (ISC)² Systems Security Certified Practitioner...
# 1        743  A Crash Course in Causality:  Inferring Causal...
# 2        874                     A Crash Course in Data Science
# 3        413                            A Law Student's Toolkit
# 4        635                A Life of Happiness and Fulfillment
#
#           course_organization course_Certificate_type  course_rating  \
# 0                      (ISC)²          SPECIALIZATION            4.7
# 1  University of Pennsylvania                  COURSE            4.7
# 2    Johns Hopkins University                  COURSE            4.5
# 3             Yale University                  COURSE            4.7
# 4   Indian School of Business                  COURSE            4.8
#
#   course_difficulty course_students_enrolled
# 0          Beginner                     5.3k
# 1      Intermediate                      17k
# ...

# %%
df1.shape
# Out:
# (891, 7)

# %%
df1_original = df1.copy()

# %%
df1_100 = df1_original.sample(100, random_state=42)

# %%
df1_100.shape
# Out:
# (100, 7)

# %%
df1_100.isnull().sum()
# Out:
# course_id                   0
# course_title                0
# course_organization         0
# course_Certificate_type     0
# course_rating               0
# course_difficulty           0
# course_students_enrolled    0
# dtype: int64

# %%
df1_100.duplicated().sum()
# Out:
# 0

# %%
df1_100.columns
# Out:
# Index(['course_id', 'course_title', 'course_organization',
#        'course_Certificate_type', 'course_rating', 'course_difficulty',
#        'course_students_enrolled'],
#       dtype='object')

# %%
course_data = df1_100[
    [
    'course_title',
    'course_rating',
    'course_difficulty'
    ]
]

course_data.head()
# Out:
#                                           course_title  course_rating  \
# 709                                     SAS Programmer            4.8
# 439                              Innovation Management            4.6
# 840                     Understanding Research Methods            4.5
# 720  Security & Safety Challenges in a Globalized W...            4.7
# 39           Algorithms for Battery Management Systems            4.8
#
#     course_difficulty
# 709          Beginner
# 439          Beginner
# 840             Mixed
# 720          Beginner
# 39       Intermediate

# %%
difficulty_count = df1_100['course_difficulty'].value_counts()

difficulty_count
# Out:
# course_difficulty
# Beginner        59
# Intermediate    20
# Mixed           19
# Advanced         2
# Name: count, dtype: int64

# %%
difficulty_count.plot(
    kind='bar',
    figsize=(6,4)
)

plt.xlabel("Difficulty Level")
plt.ylabel("Number of Courses")
plt.title("Course Difficulty Distribution")

plt.show()

# %%
df1_100['course_rating'].describe()
# Out:
# count    100.000000
# mean       4.698000
# std        0.118048
# min        4.400000
# 25%        4.600000
# 50%        4.700000
# 75%        4.800000
# max        4.900000
# Name: course_rating, dtype: float64

# %%
org_count = df1_100['course_organization'].value_counts().head(10)

org_count
# Out:
# course_organization
# University of Pennsylvania           5
# Duke University                      4
# University of Virginia               4
# Yale University                      4
# Google Cloud                         4
# University of Michigan               3
# Johns Hopkins University             3
# Rice University                      3
# Saint Petersburg State University    2
# LearnQuest                           2
# Name: count, dtype: int64

# %%
org_count.plot(
    kind='bar',
    figsize=(8,4)
)

plt.xlabel("Organization")
plt.ylabel("Number of Courses")

plt.title("Top Course Organizations")

plt.xticks(rotation=45)

plt.show()

# %%
plt.hist(
    df1_100['course_students_enrolled']
)

plt.xlabel("Students Enrolled")
plt.ylabel("Number of Courses")

plt.title("Course Enrollment Distribution")

plt.show()

# %%
sns.boxplot(
    data=df1_100,
    x='course_difficulty',
    y='course_rating'
)

plt.title("Rating Comparison Based on Difficulty")

plt.show()

# %%
df1_100['combined_features'] = (
    df1_100['course_title']
    + " "
    + df1_100['course_difficulty']
)

# %%
import pandas as pd
import numpy as np

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
courses = pd.read_csv("courses.csv")

courses.head()
# Out:
#    course_id                                       course_title  \
# 0        134  (ISC)² Systems Security Certified Practitioner...
# 1        743  A Crash Course in Causality:  Inferring Causal...
# 2        874                     A Crash Course in Data Science
# 3        413                            A Law Student's Toolkit
# 4        635                A Life of Happiness and Fulfillment
#
#           course_organization course_Certificate_type  course_rating  \
# 0                      (ISC)²          SPECIALIZATION            4.7
# 1  University of Pennsylvania                  COURSE            4.7
# 2    Johns Hopkins University                  COURSE            4.5
# 3             Yale University                  COURSE            4.7
# 4   Indian School of Business                  COURSE            4.8
#
#   course_difficulty course_students_enrolled
# 0          Beginner                     5.3k
# 1      Intermediate                      17k
# ...

# %%
courses['combined_features'] = (
    courses['course_title'].astype(str)
    + " "
    + courses['course_organization'].astype(str)
    + " "
    + courses['course_difficulty'].astype(str)
)
